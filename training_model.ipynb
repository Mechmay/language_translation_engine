# %%
import import_ipynb
from preprocessing import num_encoder_tokens, num_decoder_tokens, decoder_target_data, encoder_input_data, decoder_input_data, decoder_target_data

from tensorflow import keras
# Add Dense to the imported layers
from keras.layers import Input, LSTM, Dense
from keras.models import Model

# UNCOMMENT THE TWO LINES BELOW IF YOU ARE GETTING ERRORS ON A MAC
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# Choose a dimensionality
latent_dim = 150

# Choose a batch size
# and a larger number of epochs:
batch_size = 50
epochs = 60

# Encoder training setup
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder_lstm = LSTM(latent_dim, return_state=True)
encoder_outputs, state_hidden, state_cell = encoder_lstm(encoder_inputs)
encoder_states = [state_hidden, state_cell]

# Decoder training setup:
decoder_inputs = Input(shape=(None, num_decoder_tokens))
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, decoder_state_hidden, decoder_state_cell = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# Building the training model:
training_model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

print("Model summary:\n")
training_model.summary()
print("\n\n")

# Compile the model:
training_model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# print("Training the model:\n")
# Train the model:
training_model.fit([encoder_input_data, decoder_input_data], decoder_target_data, batch_size = batch_size, epochs = epochs, validation_split = 0.2)

training_model.save('training_model.h5')
# Out:
# Model summary:
#
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, None, 161)    0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            (None, None, 409)    0
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, 150), (None, 187200      input_3[0][0]
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   [(None, None, 150),  336000      input_4[0][0]
#                                                                  lstm_3[0][1]
#                                                                  lstm_3[0][2]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, None, 409)    61759       lstm_4[0][0]
# ==================================================================================================
# Total params: 584,959
# Trainable params: 584,959
# Non-trainable params: 0
# __________________________________________________________________________________________________
#
#
#
# Train on 400 samples, validate on 101 samples
# Epoch 1/60
# 400/400 [==============================] - 10s 26ms/step - loss: 1.7571 - accuracy: 0.0632 - val_loss: 1.3225 - val_accuracy: 0.0714
# Epoch 2/60
# 400/400 [==============================] - 2s 6ms/step - loss: 1.2066 - accuracy: 0.0714 - val_loss: 1.1460 - val_accuracy: 0.0714
# Epoch 3/60
# 400/400 [==============================] - 2s 6ms/step - loss: 1.1370 - accuracy: 0.0750 - val_loss: 1.1487 - val_accuracy: 0.0714
# Epoch 4/60
# 400/400 [==============================] - 2s 6ms/step - loss: 1.1193 - accuracy: 0.0823 - val_loss: 1.1551 - val_accuracy: 0.0870
# Epoch 5/60
# 400/400 [==============================] - 3s 7ms/step - loss: 1.1059 - accuracy: 0.0898 - val_loss: 1.1641 - val_accuracy: 0.0877
# Epoch 6/60
# 400/400 [==============================] - 3s 8ms/step - loss: 1.0898 - accuracy: 0.0889 - val_loss: 1.1687 - val_accuracy: 0.0877
# Epoch 7/60
# 400/400 [==============================] - 3s 7ms/step - loss: 1.0778 - accuracy: 0.0880 - val_loss: 1.1696 - val_accuracy: 0.0905
# Epoch 8/60
# 400/400 [==============================] - 2s 5ms/step - loss: 1.0624 - accuracy: 0.0918 - val_loss: 1.2068 - val_accuracy: 0.0877
# Epoch 9/60
# 400/400 [==============================] - 2s 6ms/step - loss: 1.0569 - accuracy: 0.0936 - val_loss: 1.1821 - val_accuracy: 0.1004
# Epoch 10/60
# 400/400 [==============================] - 3s 7ms/step - loss: 1.0431 - accuracy: 0.1004 - val_loss: 1.2188 - val_accuracy: 0.0919
# Epoch 11/60
# 400/400 [==============================] - 3s 7ms/step - loss: 1.0289 - accuracy: 0.1032 - val_loss: 1.1950 - val_accuracy: 0.0820
# Epoch 12/60
# 400/400 [==============================] - 3s 7ms/step - loss: 1.0177 - accuracy: 0.1061 - val_loss: 1.2036 - val_accuracy: 0.1040
# Epoch 13/60
# 400/400 [==============================] - 3s 7ms/step - loss: 0.9992 - accuracy: 0.1095 - val_loss: 1.2456 - val_accuracy: 0.0962
# Epoch 14/60
# 400/400 [==============================] - 3s 8ms/step - loss: 0.9972 - accuracy: 0.1086 - val_loss: 1.2264 - val_accuracy: 0.1011
# Epoch 15/60
# 400/400 [==============================] - 3s 7ms/step - loss: 0.9723 - accuracy: 0.1150 - val_loss: 1.2304 - val_accuracy: 0.1040
# Epoch 16/60
# 400/400 [==============================] - 2s 6ms/step - loss: 0.9656 - accuracy: 0.1134 - val_loss: 1.2564 - val_accuracy: 0.0969
# Epoch 17/60
# 400/400 [==============================] - 2s 6ms/step - loss: 0.9426 - accuracy: 0.1202 - val_loss: 1.2568 - val_accuracy: 0.1011
# Epoch 18/60
# 400/400 [==============================] - 3s 7ms/step - loss: 0.9352 - accuracy: 0.1227 - val_loss: 1.2392 - val_accuracy: 0.0997
# Epoch 19/60
# 400/400 [==============================] - 3s 6ms/step - loss: 0.9181 - accuracy: 0.1262 - val_loss: 1.2634 - val_accuracy: 0.1040
# Epoch 20/60
# 400/400 [==============================] - 2s 5ms/step - loss: 0.9067 - accuracy: 0.1268 - val_loss: 1.2525 - val_accuracy: 0.1082
# Epoch 21/60
# 400/400 [==============================] - 2s 6ms/step - loss: 0.8819 - accuracy: 0.1343 - val_loss: 1.2456 - val_accuracy: 0.1040
# Epoch 22/60
# 400/400 [==============================] - 2s 5ms/step - loss: 0.8788 - accuracy: 0.1330 - val_loss: 1.2690 - val_accuracy: 0.1075
# Epoch 23/60
# 400/400 [==============================] - 2s 5ms/step - loss: 0.8534 - accuracy: 0.1379 - val_loss: 1.2633 - val_accuracy: 0.1075
# Epoch 24/60
# 400/400 [==============================] - 2s 5ms/step - loss: 0.8394 - accuracy: 0.1411 - val_loss: 1.2756 - val_accuracy: 0.1110
# Epoch 25/60
# 400/400 [==============================] - 2s 5ms/step - loss: 0.8229 - accuracy: 0.1425 - val_loss: 1.2669 - val_accuracy: 0.1075
# Epoch 26/60
# 400/400 [==============================] - 2s 6ms/step - loss: 0.7992 - accuracy: 0.1477 - val_loss: 1.2824 - val_accuracy: 0.1124
# Epoch 27/60
# 400/400 [==============================] - 2s 6ms/step - loss: 0.7835 - accuracy: 0.1488 - val_loss: 1.2653 - val_accuracy: 0.1146
# Epoch 28/60
# 400/400 [==============================] - 2s 6ms/step - loss: 0.7751 - accuracy: 0.1468 - val_loss: 1.2752 - val_accuracy: 0.1132
# Epoch 29/60
# 400/400 [==============================] - 2s 6ms/step - loss: 0.7437 - accuracy: 0.1545 - val_loss: 1.2699 - val_accuracy: 0.1103
# Epoch 30/60
# 400/400 [==============================] - 3s 6ms/step - loss: 0.7401 - accuracy: 0.1509 - val_loss: 1.2828 - val_accuracy: 0.1153
# Epoch 31/60
# 400/400 [==============================] - 2s 6ms/step - loss: 0.7138 - accuracy: 0.1600 - val_loss: 1.3542 - val_accuracy: 0.0919
# Epoch 32/60
# 400/400 [==============================] - 3s 6ms/step - loss: 0.7083 - accuracy: 0.1579 - val_loss: 1.3100 - val_accuracy: 0.1061
# Epoch 33/60
# 400/400 [==============================] - 2s 5ms/step - loss: 0.6954 - accuracy: 0.1582 - val_loss: 1.2819 - val_accuracy: 0.1089
# Epoch 34/60
# 400/400 [==============================] - 2s 6ms/step - loss: 0.6702 - accuracy: 0.1652 - val_loss: 1.2731 - val_accuracy: 0.1153
# Epoch 35/60
# 400/400 [==============================] - 3s 6ms/step - loss: 0.6611 - accuracy: 0.1668 - val_loss: 1.2932 - val_accuracy: 0.1711
# Epoch 36/60
# 400/400 [==============================] - 3s 7ms/step - loss: 0.6486 - accuracy: 0.1761 - val_loss: 1.2837 - val_accuracy: 0.1160
# Epoch 37/60
# 400/400 [==============================] - 3s 6ms/step - loss: 0.6304 - accuracy: 0.1688 - val_loss: 1.2705 - val_accuracy: 0.1174
# Epoch 38/60
# 400/400 [==============================] - 2s 5ms/step - loss: 0.6168 - accuracy: 0.1693 - val_loss: 1.3276 - val_accuracy: 0.1117
# Epoch 39/60
# 400/400 [==============================] - 2s 5ms/step - loss: 0.6151 - accuracy: 0.1689 - val_loss: 1.2912 - val_accuracy: 0.1160
# Epoch 40/60
# 400/400 [==============================] - 2s 6ms/step - loss: 0.5902 - accuracy: 0.1713 - val_loss: 1.2741 - val_accuracy: 0.1216
# Epoch 41/60
# 400/400 [==============================] - 2s 5ms/step - loss: 0.5753 - accuracy: 0.1734 - val_loss: 1.2707 - val_accuracy: 0.1330
# Epoch 42/60
# 400/400 [==============================] - 3s 7ms/step - loss: 0.5709 - accuracy: 0.1782 - val_loss: 1.2743 - val_accuracy: 0.1195
# Epoch 43/60
# 400/400 [==============================] - 3s 7ms/step - loss: 0.5487 - accuracy: 0.1798 - val_loss: 1.2657 - val_accuracy: 0.1280
# Epoch 44/60
# 400/400 [==============================] - 4s 9ms/step - loss: 0.5460 - accuracy: 0.1809 - val_loss: 1.2899 - val_accuracy: 0.1174
# Epoch 45/60
# 400/400 [==============================] - 3s 7ms/step - loss: 0.5245 - accuracy: 0.1827 - val_loss: 1.2714 - val_accuracy: 0.1252
# Epoch 46/60
# 400/400 [==============================] - 3s 7ms/step - loss: 0.5113 - accuracy: 0.1839 - val_loss: 1.2858 - val_accuracy: 0.1252
# Epoch 47/60
# 400/400 [==============================] - 2s 6ms/step - loss: 0.5114 - accuracy: 0.1855 - val_loss: 1.2745 - val_accuracy: 0.1245
# Epoch 48/60
# 400/400 [==============================] - 2s 5ms/step - loss: 0.4888 - accuracy: 0.1887 - val_loss: 1.2842 - val_accuracy: 0.1223
# Epoch 49/60
# 400/400 [==============================] - 2s 5ms/step - loss: 0.4824 - accuracy: 0.1866 - val_loss: 1.2667 - val_accuracy: 0.1266
# Epoch 50/60
# 400/400 [==============================] - 2s 5ms/step - loss: 0.4677 - accuracy: 0.1904 - val_loss: 1.2672 - val_accuracy: 0.1308
# Epoch 51/60
# 400/400 [==============================] - 8s 21ms/step - loss: 0.4704 - accuracy: 0.1918 - val_loss: 1.2790 - val_accuracy: 0.1231
# Epoch 52/60
# 400/400 [==============================] - 4s 10ms/step - loss: 0.4501 - accuracy: 0.1921 - val_loss: 1.2711 - val_accuracy: 0.1280
# Epoch 53/60
# 400/400 [==============================] - 4s 10ms/step - loss: 0.4424 - accuracy: 0.1914 - val_loss: 1.2869 - val_accuracy: 0.1231
# Epoch 54/60
# 400/400 [==============================] - 3s 8ms/step - loss: 0.4301 - accuracy: 0.1955 - val_loss: 1.2815 - val_accuracy: 0.1308
# Epoch 55/60
# 400/400 [==============================] - 3s 8ms/step - loss: 0.4198 - accuracy: 0.1959 - val_loss: 1.2808 - val_accuracy: 0.1393
# Epoch 56/60
# 400/400 [==============================] - 3s 8ms/step - loss: 0.4194 - accuracy: 0.1989 - val_loss: 1.2787 - val_accuracy: 0.1273
# Epoch 57/60
# 400/400 [==============================] - 3s 8ms/step - loss: 0.4046 - accuracy: 0.1980 - val_loss: 1.2802 - val_accuracy: 0.1301
# Epoch 58/60
# 400/400 [==============================] - 3s 7ms/step - loss: 0.4016 - accuracy: 0.2027 - val_loss: 1.2774 - val_accuracy: 0.1294
# Epoch 59/60
# 400/400 [==============================] - 3s 7ms/step - loss: 0.3872 - accuracy: 0.2021 - val_loss: 1.2850 - val_accuracy: 0.1308
# Epoch 60/60
# 400/400 [==============================] - 3s 7ms/step - loss: 0.3817 - accuracy: 0.2032 - val_loss: 1.2848 - val_accuracy: 0.1252
